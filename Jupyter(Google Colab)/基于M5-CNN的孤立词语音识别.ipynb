# %% [markdown]
# 采用PyTorch搭建卷积神经网络(CNN)并进行以下孤立词的简单语音识别：
# 1. 打开后备箱
# 2. 关闭后备箱
# 3. 开后备箱
# 4. 关后备箱
# @Vela

# %% [markdown]
# 运行前推荐选择“代码执行程序-更改运行时类型-硬件加速器-GPU”
# @Vela

# %%
# !git clone https://github.com/Vela-Yang/Speech-Recognize-via-CNN.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline

# %% [markdown]
# 导入PyTorch相关的库

# %%
# !pip install torchaudio
# !pip install pydub
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: torch==1.8.1 in /usr/local/lib/python3.7/dist-packages (from torchaudio) (1.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1->torchaudio) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1->torchaudio) (1.19.5)
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (0.25.1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# 导入数据库

# %%
import os
from typing import Tuple, Optional, Union
from pathlib import Path

from torchaudio import load as AudioLoad
from torch.utils.data import Dataset
from torch import Tensor


FOLDER_IN_ARCHIVE = "MyDataset"
EXCEPT_FOLDER = "_background_noise_"

# 加载列表
def _load_list(root, *filenames):
    output = []
    for filename in filenames:
        filepath = os.path.join(root, filename)
        with open(filepath) as fileobj:
            output += [os.path.normpath(os.path.join(root, line.strip())) for line in fileobj]
    return output

# 加载语音
def load_item(filepath: str, path: str) -> Tuple[Tensor, int, str, str, int]:
    relpath = os.path.relpath(filepath, path)
    label, filename = os.path.split(relpath)
    # Load audio
    waveform, sample_rate = AudioLoad(filepath)
    return waveform, sample_rate, label

# 定义数据集类
class MyDataset(Dataset):

    # 初始化方法
    def __init__(self,
                 root: Union[str, Path],
                 folder_in_archive: str = FOLDER_IN_ARCHIVE,
                 subset: Optional[str] = None,
                 ) -> None:

        assert subset is None or subset in ["training", "validation", "testing"], (
            "When `subset` not None, it must take a value from "
            + "{'training', 'validation', 'testing'}."
        )

        root = os.fspath(root)

        self._path = os.path.join(root, folder_in_archive)


        if subset == "validation":
            self._walker = _load_list(self._path, "validation_list.txt")
        elif subset == "testing":
            self._walker = _load_list(self._path, "testing_list.txt")
        elif subset == "training":
            excludes = set(_load_list(self._path, "validation_list.txt", "testing_list.txt"))
            walker = sorted(str(p) for p in Path(self._path).glob('*/*.wav'))
            self._walker = [
                w for w in walker
                if EXCEPT_FOLDER not in w
                and os.path.normpath(w) not in excludes
            ]
        else:
            walker = sorted(str(p) for p in Path(self._path).glob('*/*.wav'))
            self._walker = [w for w in walker if EXCEPT_FOLDER not in w]

    # 定义得到样本方法
    def __getitem__(self, n: int) -> Tuple[Tensor, int, str, str, int]:
        fileid = self._walker[n]
        return load_item(fileid, self._path)


    def __len__(self) -> int:
        return len(self._walker)

# %% [markdown]
# 建立数据集子集，包括训练集、测试集与有效集

# %%
import os


class SubsetSC(MyDataset):
    def __init__(self, subset: str = None):
        super().__init__("./Speech-Recognize-via-CNN/")

        def load_list(filename):
            filepath = os.path.join(self._path, filename)
            with open(filepath, encoding='utf8') as fileobj:
                return [os.path.join(self._path, line.strip()) for line in fileobj]

        if subset == "validation":
            self._walker = load_list("validation_list.txt")
        elif subset == "testing":
            self._walker = load_list("testing_list.txt")
        elif subset == "training":
            excludes = load_list("validation_list.txt") + load_list("testing_list.txt")
            excludes = set(excludes)
            self._walker = [w for w in self._walker if w not in excludes]


# Create training and testing split of the data. We do not use validation in this tutorial.
train_set = SubsetSC("training")
test_set = SubsetSC("testing")

waveform, sample_rate, label = train_set[0]

# %% [markdown]
# 展示一个来自训练集的音频信息

# %%
print("波形长度 {}".format(waveform.size()))
print("波形采样率 {}".format(sample_rate))

plt.plot(waveform.t().numpy())
# Out:
# 波形长度 torch.Size([1, 16395])
# 波形采样率 8000

# %% [markdown]
# 列出音频标签

# %%
labels = sorted(list(set(datapoint[2] for datapoint in train_set)))
labels
# Out:
# ['(关)闭后备箱', '(打)开后备箱']

# %% [markdown]
# 列举几个声音样本
# 这个是“打开后备箱”

# %%
waveform_first, sample_first, label_first = train_set[0]
ipd.Audio(waveform_first.numpy(), rate=sample_first)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 这个是“关后备箱”

# %%
waveform_last, sample_last, label_last = train_set[-1]
ipd.Audio(waveform_last.numpy(), rate=sample_last)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 对音频信号重采样（统一采样率）
# 由于大家设备不同，导致录制的音频也不同。
# 同时，8000Hz完全可以胜任语音采样。
# 这里听一下重采样后的信号

# %%
new_sample_rate = 8000
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
transformed = transform(waveform_last)
print(transformed)
plt.plot(transformed.t().numpy())
ipd.Audio(transformed.numpy(), rate=8000)
#import librosa.display
#librosa.display.specshow(librosa.power_to_db(transformed.numpy(), ref = np.max), y_axis='mel', fmax=8000, x_axis='time')
# Out:
# tensor([[4.5368e-04, 3.0916e-04, 4.8497e-04,  ..., 8.8631e-05, 1.8629e-04,
#          4.8508e-04]])
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 使用音频文件的索引来对应其标签

# %%
def label_to_index(word):
    # 返回标签对应的数据集索引
    return torch.tensor(labels.index(word))


def index_to_label(index):
    # 返回数据集索引对应的标签
    return labels[index]


word_start = "(打)开后备箱"
index = label_to_index(word_start)
word_recovered = index_to_label(index)

print(word_start, "-->", index, "-->", word_recovered)
# Out:
# (打)开后备箱 --> tensor(1) --> (打)开后备箱

# %% [markdown]
# 将信号转换成张量，适应CNN模型的输入

# %%
def pad_sequence(batch):
    # 用填充0的方法让所有张量等维
    batch = [item.t() for item in batch]
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)
    return batch.permute(0, 2, 1)


def collate_fn(batch):

    # 将数据处理成几个张量的形式并合并成一个批张量( batch tensor )

    tensors, targets = [], []

    for waveform, _, label, *_ in batch:
        tensors += [waveform]
        targets += [label_to_index(label)]

    # 将几个张量转换成批张量（张量集合，也是一个张量）
    tensors = pad_sequence(tensors)
    targets = torch.stack(targets)

    return tensors, targets


batch_size = 256

if device == "cuda":
    num_workers = 1
    pin_memory = True
else:
    num_workers = 0
    pin_memory = False

train_loader = torch.utils.data.DataLoader(
    train_set,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)
test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)

# %% [markdown]
# 神经网络定义
# 第一层为80点卷积层，在处理8000Hz音频时，帧长大约25ms。

# %%
class M5_CNN(nn.Module):
    def __init__(self, n_input=1, n_output=4, stride=4, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=200, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.bn2 = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.bn3 = nn.BatchNorm1d(2 * n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 4 * n_channel, kernel_size=3)
        self.bn4 = nn.BatchNorm1d(4 * n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1 = nn.Linear(4 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)


model = M5_CNN(n_input=transformed.shape[0], n_output=len(labels))
model.to(device)
print(model)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


n = count_parameters(model)
print("参数个数： %s" % n)
# Out:
# M5_CNN(
#   (conv1): Conv1d(1, 32, kernel_size=(200,), stride=(4,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 32, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(32, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(64, 128, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool4): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=128, out_features=2, bias=True)
# )
# 参数个数： 41218

# %% [markdown]
# 参考论文 VERY DEEP CONVOLUTIONAL NEURAL NETWORKS FOR RAW WAVEFORMS ，给出优化器的结构，其中sceduler是为了在20次迭代以后降低学习率，提高泛化能力，避免过拟合

# %%
optimizer = optim.Adam(model.parameters(), lr=0.02, weight_decay=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)  # 40次迭代后开始降低学习率，避免过拟合

# %% [markdown]
# 训练，测试网络
# --------------------------------
#
# 训练：根据数据集进行学习
#
# 测试：测试训练集的正确率

# %%
def train(model, epoch, log_interval):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):

        data = data.to(device)
        target = target.to(device)

        # 采用相同的变换方法
        data = transform(data)
        output = model(data)

        # 训练损失
        loss = F.nll_loss(output.squeeze(), target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 展示训练状态
        if batch_idx % log_interval == 0:
            print(f"迭代次数: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\t训练损失: {loss.item():.6f}")

        # 更新状态栏
        pbar.update(pbar_update)
        # 记录训练损失
        losses.append(loss.item())

# %% [markdown]
# 测试函数定义

# %%
def number_of_correct(pred, target):
    # 计算分类正确的选项
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):
    # 找到最接近的索引
    return tensor.argmax(dim=-1)


def test(model, epoch):
    model.eval()
    correct = 0
    for data, target in test_loader:

        data = data.to(device)
        target = target.to(device)

        # 所有数据的预处理方式应该均相同
        data = transform(data)
        output = model(data)

        pred = get_likely_index(output)
        correct += number_of_correct(pred, target)

        # 更新状态栏
        pbar.update(pbar_update)
        Accuracy.append(100. * correct / len(test_loader.dataset))

    print(f"\n迭代次数 {epoch}\t准确率: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")

# %% [markdown]
# 开始模型训练

# %%
log_interval = 20
n_epoch = 250

pbar_update = 1 / (len(train_loader) + len(test_loader))
losses = []
Accuracy = []

# 所有数据的预处理方式应该均相同
transform = transform.to(device)
with tqdm(total=n_epoch) as pbar:
    for epoch in range(1, n_epoch + 1):
        train(model, epoch, log_interval)
        test(model, epoch)
        scheduler.step()

# 展示训练损失与准确率
plt.subplot(2,1,1)
plt.plot(losses);
plt.title("训练损失");
plt.subplot(2,1,2)
plt.plot(Accuracy);
plt.title("训练后准确率");
# Out:
# HBox(children=(FloatProgress(value=0.0, max=250.0), HTML(value='')))
# 迭代次数: 1 [0/254 (0%)]	训练损失: 0.715087
#
# 迭代次数 1	准确率: 24/48 (50%)
#
# 迭代次数: 2 [0/254 (0%)]	训练损失: 1.301455
#
# 迭代次数 2	准确率: 24/48 (50%)
#
# 迭代次数: 3 [0/254 (0%)]	训练损失: 0.921975
#
# 迭代次数 3	准确率: 24/48 (50%)
#
# 迭代次数: 4 [0/254 (0%)]	训练损失: 0.692969
#
# 迭代次数 4	准确率: 24/48 (50%)
#
# 迭代次数: 5 [0/254 (0%)]	训练损失: 0.814488
#
# 迭代次数 5	准确率: 24/48 (50%)
#
# 迭代次数: 6 [0/254 (0%)]	训练损失: 0.847041
#
# 迭代次数 6	准确率: 24/48 (50%)
#
# 迭代次数: 7 [0/254 (0%)]	训练损失: 0.757777
#
# 迭代次数 7	准确率: 23/48 (48%)
#
# 迭代次数: 8 [0/254 (0%)]	训练损失: 0.673922
#
# 迭代次数 8	准确率: 28/48 (58%)
#
# 迭代次数: 9 [0/254 (0%)]	训练损失: 0.641219
#
# 迭代次数 9	准确率: 28/48 (58%)
#
# 迭代次数: 10 [0/254 (0%)]	训练损失: 0.637660
#
# 迭代次数 10	准确率: 30/48 (62%)
#
# 迭代次数: 11 [0/254 (0%)]	训练损失: 0.629180
#
# 迭代次数 11	准确率: 26/48 (54%)
#
# 迭代次数: 12 [0/254 (0%)]	训练损失: 0.610223
#
# 迭代次数 12	准确率: 27/48 (56%)
#
# 迭代次数: 13 [0/254 (0%)]	训练损失: 0.590084
#
# 迭代次数 13	准确率: 27/48 (56%)
#
# 迭代次数: 14 [0/254 (0%)]	训练损失: 0.568661
#
# 迭代次数 14	准确率: 29/48 (60%)
#
# 迭代次数: 15 [0/254 (0%)]	训练损失: 0.544572
#
# 迭代次数 15	准确率: 29/48 (60%)
#
# 迭代次数: 16 [0/254 (0%)]	训练损失: 0.524631
#
# 迭代次数 16	准确率: 29/48 (60%)
#
# 迭代次数: 17 [0/254 (0%)]	训练损失: 0.502754
#
# 迭代次数 17	准确率: 29/48 (60%)
#
# 迭代次数: 18 [0/254 (0%)]	训练损失: 0.489084
#
# 迭代次数 18	准确率: 30/48 (62%)
#
# 迭代次数: 19 [0/254 (0%)]	训练损失: 0.465675
#
# 迭代次数 19	准确率: 33/48 (69%)
#
# 迭代次数: 20 [0/254 (0%)]	训练损失: 0.453014
#
# 迭代次数 20	准确率: 30/48 (62%)
#
# 迭代次数: 21 [0/254 (0%)]	训练损失: 0.431793
#
# 迭代次数 21	准确率: 30/48 (62%)
#
# 迭代次数: 22 [0/254 (0%)]	训练损失: 0.410860
#
# 迭代次数 22	准确率: 32/48 (67%)
#
# 迭代次数: 23 [0/254 (0%)]	训练损失: 0.389150
#
# 迭代次数 23	准确率: 28/48 (58%)
#
# 迭代次数: 24 [0/254 (0%)]	训练损失: 0.393046
#
# 迭代次数 24	准确率: 33/48 (69%)
#
# 迭代次数: 25 [0/254 (0%)]	训练损失: 0.475128
#
# 迭代次数 25	准确率: 33/48 (69%)
#
# 迭代次数: 26 [0/254 (0%)]	训练损失: 0.333881
#
# 迭代次数 26	准确率: 28/48 (58%)
#
# 迭代次数: 27 [0/254 (0%)]	训练损失: 0.350126
#
# 迭代次数 27	准确率: 27/48 (56%)
#
# 迭代次数: 28 [0/254 (0%)]	训练损失: 0.310412
#
# 迭代次数 28	准确率: 27/48 (56%)
#
# 迭代次数: 29 [0/254 (0%)]	训练损失: 0.287641
#
# 迭代次数 29	准确率: 33/48 (69%)
#
# 迭代次数: 30 [0/254 (0%)]	训练损失: 0.270244
#
# 迭代次数 30	准确率: 32/48 (67%)
#
# 迭代次数: 31 [0/254 (0%)]	训练损失: 0.240507
#
# 迭代次数 31	准确率: 31/48 (65%)
#
# 迭代次数: 32 [0/254 (0%)]	训练损失: 0.203926
#
# 迭代次数 32	准确率: 30/48 (62%)
#
# 迭代次数: 33 [0/254 (0%)]	训练损失: 0.178251
#
# 迭代次数 33	准确率: 26/48 (54%)
#
# 迭代次数: 34 [0/254 (0%)]	训练损失: 0.171986
#
# 迭代次数 34	准确率: 41/48 (85%)
#
# 迭代次数: 35 [0/254 (0%)]	训练损失: 0.305204
#
# 迭代次数 35	准确率: 25/48 (52%)
#
# 迭代次数: 36 [0/254 (0%)]	训练损失: 0.154045
#
# 迭代次数 36	准确率: 24/48 (50%)
#
# 迭代次数: 37 [0/254 (0%)]	训练损失: 0.183967
#
# 迭代次数 37	准确率: 25/48 (52%)
#
# 迭代次数: 38 [0/254 (0%)]	训练损失: 0.119904
#
# 迭代次数 38	准确率: 28/48 (58%)
#
# 迭代次数: 39 [0/254 (0%)]	训练损失: 0.131477
#
# 迭代次数 39	准确率: 26/48 (54%)
#
# 迭代次数: 40 [0/254 (0%)]	训练损失: 0.103117
#
# 迭代次数 40	准确率: 25/48 (52%)
#
# 迭代次数: 41 [0/254 (0%)]	训练损失: 0.108076
#
# 迭代次数 41	准确率: 25/48 (52%)
#
# 迭代次数: 42 [0/254 (0%)]	训练损失: 0.102847
#
# 迭代次数 42	准确率: 25/48 (52%)
#
# 迭代次数: 43 [0/254 (0%)]	训练损失: 0.093710
#
# 迭代次数 43	准确率: 25/48 (52%)
#
# 迭代次数: 44 [0/254 (0%)]	训练损失: 0.085430
#
# 迭代次数 44	准确率: 26/48 (54%)
#
# 迭代次数: 45 [0/254 (0%)]	训练损失: 0.079690
#
# 迭代次数 45	准确率: 28/48 (58%)
#
# 迭代次数: 46 [0/254 (0%)]	训练损失: 0.076012
#
# 迭代次数 46	准确率: 29/48 (60%)
#
# 迭代次数: 47 [0/254 (0%)]	训练损失: 0.073423
#
# 迭代次数 47	准确率: 30/48 (62%)
#
# 迭代次数: 48 [0/254 (0%)]	训练损失: 0.071218
#
# 迭代次数 48	准确率: 31/48 (65%)
#
# 迭代次数: 49 [0/254 (0%)]	训练损失: 0.069065
#
# 迭代次数 49	准确率: 33/48 (69%)
#
# 迭代次数: 50 [0/254 (0%)]	训练损失: 0.066909
#
# 迭代次数 50	准确率: 33/48 (69%)
#
# 迭代次数: 51 [0/254 (0%)]	训练损失: 0.064689
#
# 迭代次数 51	准确率: 33/48 (69%)
#
# 迭代次数: 52 [0/254 (0%)]	训练损失: 0.062390
#
# 迭代次数 52	准确率: 34/48 (71%)
#
# 迭代次数: 53 [0/254 (0%)]	训练损失: 0.060028
#
# 迭代次数 53	准确率: 34/48 (71%)
#
# 迭代次数: 54 [0/254 (0%)]	训练损失: 0.057628
#
# 迭代次数 54	准确率: 34/48 (71%)
#
# 迭代次数: 55 [0/254 (0%)]	训练损失: 0.055224
#
# 迭代次数 55	准确率: 35/48 (73%)
#
# 迭代次数: 56 [0/254 (0%)]	训练损失: 0.052841
#
# 迭代次数 56	准确率: 35/48 (73%)
#
# 迭代次数: 57 [0/254 (0%)]	训练损失: 0.050523
#
# 迭代次数 57	准确率: 35/48 (73%)
#
# 迭代次数: 58 [0/254 (0%)]	训练损失: 0.048260
#
# 迭代次数 58	准确率: 37/48 (77%)
#
# 迭代次数: 59 [0/254 (0%)]	训练损失: 0.046077
#
# 迭代次数 59	准确率: 40/48 (83%)
#
# 迭代次数: 60 [0/254 (0%)]	训练损失: 0.044022
#
# 迭代次数 60	准确率: 43/48 (90%)
#
# 迭代次数: 61 [0/254 (0%)]	训练损失: 0.042128
#
# 迭代次数 61	准确率: 44/48 (92%)
#
# 迭代次数: 62 [0/254 (0%)]	训练损失: 0.040416
#
# 迭代次数 62	准确率: 45/48 (94%)
#
# 迭代次数: 63 [0/254 (0%)]	训练损失: 0.038829
#
# 迭代次数 63	准确率: 48/48 (100%)
#
# 迭代次数: 64 [0/254 (0%)]	训练损失: 0.037331
#
# 迭代次数 64	准确率: 48/48 (100%)
#
# 迭代次数: 65 [0/254 (0%)]	训练损失: 0.035871
#
# 迭代次数 65	准确率: 48/48 (100%)
#
# 迭代次数: 66 [0/254 (0%)]	训练损失: 0.034444
#
# 迭代次数 66	准确率: 48/48 (100%)
#
# 迭代次数: 67 [0/254 (0%)]	训练损失: 0.033046
#
# 迭代次数 67	准确率: 48/48 (100%)
#
# 迭代次数: 68 [0/254 (0%)]	训练损失: 0.031714
#
# 迭代次数 68	准确率: 48/48 (100%)
#
# 迭代次数: 69 [0/254 (0%)]	训练损失: 0.030484
#
# 迭代次数 69	准确率: 48/48 (100%)
#
# 迭代次数: 70 [0/254 (0%)]	训练损失: 0.029393
#
# 迭代次数 70	准确率: 48/48 (100%)
#
# 迭代次数: 71 [0/254 (0%)]	训练损失: 0.028438
#
# 迭代次数 71	准确率: 48/48 (100%)
#
# 迭代次数: 72 [0/254 (0%)]	训练损失: 0.027615
#
# 迭代次数 72	准确率: 48/48 (100%)
#
# 迭代次数: 73 [0/254 (0%)]	训练损失: 0.026884
#
# 迭代次数 73	准确率: 48/48 (100%)
#
# 迭代次数: 74 [0/254 (0%)]	训练损失: 0.026167
#
# 迭代次数 74	准确率: 48/48 (100%)
#
# 迭代次数: 75 [0/254 (0%)]	训练损失: 0.025399
#
# 迭代次数 75	准确率: 48/48 (100%)
#
# 迭代次数: 76 [0/254 (0%)]	训练损失: 0.024573
#
# 迭代次数 76	准确率: 48/48 (100%)
#
# 迭代次数: 77 [0/254 (0%)]	训练损失: 0.023732
#
# 迭代次数 77	准确率: 48/48 (100%)
#
# 迭代次数: 78 [0/254 (0%)]	训练损失: 0.022925
#
# 迭代次数 78	准确率: 48/48 (100%)
#
# 迭代次数: 79 [0/254 (0%)]	训练损失: 0.022180
#
# 迭代次数 79	准确率: 48/48 (100%)
#
# 迭代次数: 80 [0/254 (0%)]	训练损失: 0.021488
#
# 迭代次数 80	准确率: 48/48 (100%)
#
# 迭代次数: 81 [0/254 (0%)]	训练损失: 0.020832
#
# 迭代次数 81	准确率: 48/48 (100%)
#
# 迭代次数: 82 [0/254 (0%)]	训练损失: 0.020766
#
# 迭代次数 82	准确率: 48/48 (100%)
#
# 迭代次数: 83 [0/254 (0%)]	训练损失: 0.020697
#
# 迭代次数 83	准确率: 48/48 (100%)
#
# 迭代次数: 84 [0/254 (0%)]	训练损失: 0.020625
#
# 迭代次数 84	准确率: 48/48 (100%)
#
# 迭代次数: 85 [0/254 (0%)]	训练损失: 0.020551
#
# 迭代次数 85	准确率: 48/48 (100%)
#
# 迭代次数: 86 [0/254 (0%)]	训练损失: 0.020475
#
# 迭代次数 86	准确率: 48/48 (100%)
#
# 迭代次数: 87 [0/254 (0%)]	训练损失: 0.020397
#
# 迭代次数 87	准确率: 48/48 (100%)
#
# 迭代次数: 88 [0/254 (0%)]	训练损失: 0.020318
#
# 迭代次数 88	准确率: 48/48 (100%)
#
# 迭代次数: 89 [0/254 (0%)]	训练损失: 0.020239
#
# 迭代次数 89	准确率: 48/48 (100%)
#
# 迭代次数: 90 [0/254 (0%)]	训练损失: 0.020159
#
# 迭代次数 90	准确率: 48/48 (100%)
#
# 迭代次数: 91 [0/254 (0%)]	训练损失: 0.020079
#
# 迭代次数 91	准确率: 48/48 (100%)
#
# 迭代次数: 92 [0/254 (0%)]	训练损失: 0.020000
#
# 迭代次数 92	准确率: 48/48 (100%)
#
# 迭代次数: 93 [0/254 (0%)]	训练损失: 0.019921
#
# 迭代次数 93	准确率: 48/48 (100%)
#
# 迭代次数: 94 [0/254 (0%)]	训练损失: 0.019843
#
# 迭代次数 94	准确率: 48/48 (100%)
#
# 迭代次数: 95 [0/254 (0%)]	训练损失: 0.019767
#
# 迭代次数 95	准确率: 48/48 (100%)
#
# 迭代次数: 96 [0/254 (0%)]	训练损失: 0.019691
#
# 迭代次数 96	准确率: 48/48 (100%)
#
# 迭代次数: 97 [0/254 (0%)]	训练损失: 0.019617
#
# 迭代次数 97	准确率: 48/48 (100%)
#
# 迭代次数: 98 [0/254 (0%)]	训练损失: 0.019543
#
# 迭代次数 98	准确率: 48/48 (100%)
#
# 迭代次数: 99 [0/254 (0%)]	训练损失: 0.019471
#
# 迭代次数 99	准确率: 48/48 (100%)
#
# 迭代次数: 100 [0/254 (0%)]	训练损失: 0.019400
#
# 迭代次数 100	准确率: 48/48 (100%)
#
# 迭代次数: 101 [0/254 (0%)]	训练损失: 0.019329
#
# 迭代次数 101	准确率: 48/48 (100%)
#
# 迭代次数: 102 [0/254 (0%)]	训练损失: 0.019259
#
# 迭代次数 102	准确率: 48/48 (100%)
#
# 迭代次数: 103 [0/254 (0%)]	训练损失: 0.019190
#
# 迭代次数 103	准确率: 48/48 (100%)
#
# 迭代次数: 104 [0/254 (0%)]	训练损失: 0.019121
#
# 迭代次数 104	准确率: 48/48 (100%)
#
# 迭代次数: 105 [0/254 (0%)]	训练损失: 0.019053
#
# 迭代次数 105	准确率: 48/48 (100%)
#
# 迭代次数: 106 [0/254 (0%)]	训练损失: 0.018985
#
# 迭代次数 106	准确率: 48/48 (100%)
#
# 迭代次数: 107 [0/254 (0%)]	训练损失: 0.018918
#
# 迭代次数 107	准确率: 48/48 (100%)
#
# 迭代次数: 108 [0/254 (0%)]	训练损失: 0.018851
#
# 迭代次数 108	准确率: 48/48 (100%)
#
# 迭代次数: 109 [0/254 (0%)]	训练损失: 0.018785
#
# 迭代次数 109	准确率: 48/48 (100%)
#
# 迭代次数: 110 [0/254 (0%)]	训练损失: 0.018718
#
# 迭代次数 110	准确率: 48/48 (100%)
#
# 迭代次数: 111 [0/254 (0%)]	训练损失: 0.018651
#
# 迭代次数 111	准确率: 48/48 (100%)
#
# 迭代次数: 112 [0/254 (0%)]	训练损失: 0.018583
#
# 迭代次数 112	准确率: 48/48 (100%)
#
# 迭代次数: 113 [0/254 (0%)]	训练损失: 0.018516
#
# 迭代次数 113	准确率: 48/48 (100%)
#
# 迭代次数: 114 [0/254 (0%)]	训练损失: 0.018449
#
# 迭代次数 114	准确率: 48/48 (100%)
#
# 迭代次数: 115 [0/254 (0%)]	训练损失: 0.018381
#
# 迭代次数 115	准确率: 48/48 (100%)
#
# 迭代次数: 116 [0/254 (0%)]	训练损失: 0.018314
#
# 迭代次数 116	准确率: 48/48 (100%)
#
# 迭代次数: 117 [0/254 (0%)]	训练损失: 0.018247
#
# 迭代次数 117	准确率: 48/48 (100%)
#
# 迭代次数: 118 [0/254 (0%)]	训练损失: 0.018180
#
# 迭代次数 118	准确率: 48/48 (100%)
#
# 迭代次数: 119 [0/254 (0%)]	训练损失: 0.018113
#
# 迭代次数 119	准确率: 48/48 (100%)
#
# 迭代次数: 120 [0/254 (0%)]	训练损失: 0.018046
#
# 迭代次数 120	准确率: 48/48 (100%)
#
# 迭代次数: 121 [0/254 (0%)]	训练损失: 0.017980
#
# 迭代次数 121	准确率: 48/48 (100%)
#
# 迭代次数: 122 [0/254 (0%)]	训练损失: 0.017973
#
# 迭代次数 122	准确率: 48/48 (100%)
#
# 迭代次数: 123 [0/254 (0%)]	训练损失: 0.017966
#
# 迭代次数 123	准确率: 48/48 (100%)
#
# 迭代次数: 124 [0/254 (0%)]	训练损失: 0.017960
#
# 迭代次数 124	准确率: 48/48 (100%)
#
# 迭代次数: 125 [0/254 (0%)]	训练损失: 0.017953
#
# 迭代次数 125	准确率: 48/48 (100%)
#
# 迭代次数: 126 [0/254 (0%)]	训练损失: 0.017946
#
# 迭代次数 126	准确率: 48/48 (100%)
#
# 迭代次数: 127 [0/254 (0%)]	训练损失: 0.017940
#
# 迭代次数 127	准确率: 48/48 (100%)
#
# 迭代次数: 128 [0/254 (0%)]	训练损失: 0.017933
#
# 迭代次数 128	准确率: 48/48 (100%)
#
# 迭代次数: 129 [0/254 (0%)]	训练损失: 0.017926
#
# 迭代次数 129	准确率: 48/48 (100%)
#
# 迭代次数: 130 [0/254 (0%)]	训练损失: 0.017920
#
# 迭代次数 130	准确率: 48/48 (100%)
#
# 迭代次数: 131 [0/254 (0%)]	训练损失: 0.017913
#
# 迭代次数 131	准确率: 48/48 (100%)
#
# 迭代次数: 132 [0/254 (0%)]	训练损失: 0.017906
#
# 迭代次数 132	准确率: 48/48 (100%)
#
# 迭代次数: 133 [0/254 (0%)]	训练损失: 0.017900
#
# 迭代次数 133	准确率: 48/48 (100%)
#
# 迭代次数: 134 [0/254 (0%)]	训练损失: 0.017893
#
# 迭代次数 134	准确率: 48/48 (100%)
#
# 迭代次数: 135 [0/254 (0%)]	训练损失: 0.017886
#
# 迭代次数 135	准确率: 48/48 (100%)
#
# 迭代次数: 136 [0/254 (0%)]	训练损失: 0.017879
#
# 迭代次数 136	准确率: 48/48 (100%)
#
# 迭代次数: 137 [0/254 (0%)]	训练损失: 0.017873
#
# 迭代次数 137	准确率: 48/48 (100%)
#
# 迭代次数: 138 [0/254 (0%)]	训练损失: 0.017866
#
# 迭代次数 138	准确率: 48/48 (100%)
#
# 迭代次数: 139 [0/254 (0%)]	训练损失: 0.017859
#
# 迭代次数 139	准确率: 48/48 (100%)
#
# 迭代次数: 140 [0/254 (0%)]	训练损失: 0.017852
#
# 迭代次数 140	准确率: 48/48 (100%)
#
# 迭代次数: 141 [0/254 (0%)]	训练损失: 0.017845
#
# 迭代次数 141	准确率: 48/48 (100%)
#
# 迭代次数: 142 [0/254 (0%)]	训练损失: 0.017839
#
# 迭代次数 142	准确率: 48/48 (100%)
#
# 迭代次数: 143 [0/254 (0%)]	训练损失: 0.017832
#
# 迭代次数 143	准确率: 48/48 (100%)
#
# 迭代次数: 144 [0/254 (0%)]	训练损失: 0.017825
#
# 迭代次数 144	准确率: 48/48 (100%)
#
# 迭代次数: 145 [0/254 (0%)]	训练损失: 0.017818
#
# 迭代次数 145	准确率: 48/48 (100%)
#
# 迭代次数: 146 [0/254 (0%)]	训练损失: 0.017811
#
# 迭代次数 146	准确率: 48/48 (100%)
#
# 迭代次数: 147 [0/254 (0%)]	训练损失: 0.017804
#
# 迭代次数 147	准确率: 48/48 (100%)
#
# 迭代次数: 148 [0/254 (0%)]	训练损失: 0.017797
#
# 迭代次数 148	准确率: 48/48 (100%)
#
# 迭代次数: 149 [0/254 (0%)]	训练损失: 0.017790
#
# 迭代次数 149	准确率: 48/48 (100%)
#
# 迭代次数: 150 [0/254 (0%)]	训练损失: 0.017784
#
# 迭代次数 150	准确率: 48/48 (100%)
#
# 迭代次数: 151 [0/254 (0%)]	训练损失: 0.017777
#
# 迭代次数 151	准确率: 48/48 (100%)
#
# 迭代次数: 152 [0/254 (0%)]	训练损失: 0.017770
#
# 迭代次数 152	准确率: 48/48 (100%)
#
# 迭代次数: 153 [0/254 (0%)]	训练损失: 0.017763
#
# 迭代次数 153	准确率: 48/48 (100%)
#
# 迭代次数: 154 [0/254 (0%)]	训练损失: 0.017756
#
# 迭代次数 154	准确率: 48/48 (100%)
#
# 迭代次数: 155 [0/254 (0%)]	训练损失: 0.017749
#
# 迭代次数 155	准确率: 48/48 (100%)
#
# 迭代次数: 156 [0/254 (0%)]	训练损失: 0.017742
#
# 迭代次数 156	准确率: 48/48 (100%)
#
# 迭代次数: 157 [0/254 (0%)]	训练损失: 0.017735
#
# 迭代次数 157	准确率: 48/48 (100%)
#
# 迭代次数: 158 [0/254 (0%)]	训练损失: 0.017728
#
# 迭代次数 158	准确率: 48/48 (100%)
#
# 迭代次数: 159 [0/254 (0%)]	训练损失: 0.017721
#
# 迭代次数 159	准确率: 48/48 (100%)
#
# 迭代次数: 160 [0/254 (0%)]	训练损失: 0.017714
#
# 迭代次数 160	准确率: 48/48 (100%)
#
# 迭代次数: 161 [0/254 (0%)]	训练损失: 0.017707
#
# 迭代次数 161	准确率: 48/48 (100%)
#
# 迭代次数: 162 [0/254 (0%)]	训练损失: 0.017706
#
# 迭代次数 162	准确率: 48/48 (100%)
#
# 迭代次数: 163 [0/254 (0%)]	训练损失: 0.017705
#
# 迭代次数 163	准确率: 48/48 (100%)
#
# 迭代次数: 164 [0/254 (0%)]	训练损失: 0.017705
#
# 迭代次数 164	准确率: 48/48 (100%)
#
# 迭代次数: 165 [0/254 (0%)]	训练损失: 0.017704
#
# 迭代次数 165	准确率: 48/48 (100%)
#
# 迭代次数: 166 [0/254 (0%)]	训练损失: 0.017703
#
# 迭代次数 166	准确率: 48/48 (100%)
#
# 迭代次数: 167 [0/254 (0%)]	训练损失: 0.017702
#
# 迭代次数 167	准确率: 48/48 (100%)
#
# 迭代次数: 168 [0/254 (0%)]	训练损失: 0.017702
#
# 迭代次数 168	准确率: 48/48 (100%)
#
# 迭代次数: 169 [0/254 (0%)]	训练损失: 0.017701
#
# 迭代次数 169	准确率: 48/48 (100%)
#
# 迭代次数: 170 [0/254 (0%)]	训练损失: 0.017700
#
# 迭代次数 170	准确率: 48/48 (100%)
#
# 迭代次数: 171 [0/254 (0%)]	训练损失: 0.017700
#
# 迭代次数 171	准确率: 48/48 (100%)
#
# 迭代次数: 172 [0/254 (0%)]	训练损失: 0.017699
#
# 迭代次数 172	准确率: 48/48 (100%)
#
# 迭代次数: 173 [0/254 (0%)]	训练损失: 0.017698
#
# 迭代次数 173	准确率: 48/48 (100%)
#
# 迭代次数: 174 [0/254 (0%)]	训练损失: 0.017697
#
# 迭代次数 174	准确率: 48/48 (100%)
#
# 迭代次数: 175 [0/254 (0%)]	训练损失: 0.017697
#
# 迭代次数 175	准确率: 48/48 (100%)
#
# 迭代次数: 176 [0/254 (0%)]	训练损失: 0.017696
#
# 迭代次数 176	准确率: 48/48 (100%)
#
# 迭代次数: 177 [0/254 (0%)]	训练损失: 0.017695
#
# 迭代次数 177	准确率: 48/48 (100%)
#
# 迭代次数: 178 [0/254 (0%)]	训练损失: 0.017694
#
# 迭代次数 178	准确率: 48/48 (100%)
#
# 迭代次数: 179 [0/254 (0%)]	训练损失: 0.017694
#
# 迭代次数 179	准确率: 48/48 (100%)
#
# 迭代次数: 180 [0/254 (0%)]	训练损失: 0.017693
#
# 迭代次数 180	准确率: 48/48 (100%)
#
# 迭代次数: 181 [0/254 (0%)]	训练损失: 0.017692
#
# 迭代次数 181	准确率: 48/48 (100%)
#
# 迭代次数: 182 [0/254 (0%)]	训练损失: 0.017692
#
# 迭代次数 182	准确率: 48/48 (100%)
#
# 迭代次数: 183 [0/254 (0%)]	训练损失: 0.017691
#
# 迭代次数 183	准确率: 48/48 (100%)
#
# 迭代次数: 184 [0/254 (0%)]	训练损失: 0.017690
#
# 迭代次数 184	准确率: 48/48 (100%)
#
# 迭代次数: 185 [0/254 (0%)]	训练损失: 0.017689
#
# 迭代次数 185	准确率: 48/48 (100%)
#
# 迭代次数: 186 [0/254 (0%)]	训练损失: 0.017689
#
# 迭代次数 186	准确率: 48/48 (100%)
#
# 迭代次数: 187 [0/254 (0%)]	训练损失: 0.017688
#
# 迭代次数 187	准确率: 48/48 (100%)
#
# 迭代次数: 188 [0/254 (0%)]	训练损失: 0.017687
#
# 迭代次数 188	准确率: 48/48 (100%)
#
# 迭代次数: 189 [0/254 (0%)]	训练损失: 0.017686
#
# 迭代次数 189	准确率: 48/48 (100%)
#
# 迭代次数: 190 [0/254 (0%)]	训练损失: 0.017686
#
# 迭代次数 190	准确率: 48/48 (100%)
#
# 迭代次数: 191 [0/254 (0%)]	训练损失: 0.017685
#
# 迭代次数 191	准确率: 48/48 (100%)
#
# 迭代次数: 192 [0/254 (0%)]	训练损失: 0.017684
#
# 迭代次数 192	准确率: 48/48 (100%)
#
# 迭代次数: 193 [0/254 (0%)]	训练损失: 0.017683
#
# 迭代次数 193	准确率: 48/48 (100%)
#
# 迭代次数: 194 [0/254 (0%)]	训练损失: 0.017683
#
# 迭代次数 194	准确率: 48/48 (100%)
#
# 迭代次数: 195 [0/254 (0%)]	训练损失: 0.017682
#
# 迭代次数 195	准确率: 48/48 (100%)
#
# 迭代次数: 196 [0/254 (0%)]	训练损失: 0.017681
#
# 迭代次数 196	准确率: 48/48 (100%)
#
# 迭代次数: 197 [0/254 (0%)]	训练损失: 0.017680
#
# 迭代次数 197	准确率: 48/48 (100%)
#
# 迭代次数: 198 [0/254 (0%)]	训练损失: 0.017680
#
# 迭代次数 198	准确率: 48/48 (100%)
#
# 迭代次数: 199 [0/254 (0%)]	训练损失: 0.017679
#
# 迭代次数 199	准确率: 48/48 (100%)
#
# 迭代次数: 200 [0/254 (0%)]	训练损失: 0.017678
#
# 迭代次数 200	准确率: 48/48 (100%)
#
# 迭代次数: 201 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 201	准确率: 48/48 (100%)
#
# 迭代次数: 202 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 202	准确率: 48/48 (100%)
#
# 迭代次数: 203 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 203	准确率: 48/48 (100%)
#
# 迭代次数: 204 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 204	准确率: 48/48 (100%)
#
# 迭代次数: 205 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 205	准确率: 48/48 (100%)
#
# 迭代次数: 206 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 206	准确率: 48/48 (100%)
#
# 迭代次数: 207 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 207	准确率: 48/48 (100%)
#
# 迭代次数: 208 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 208	准确率: 48/48 (100%)
#
# 迭代次数: 209 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 209	准确率: 48/48 (100%)
#
# 迭代次数: 210 [0/254 (0%)]	训练损失: 0.017677
#
# 迭代次数 210	准确率: 48/48 (100%)
#
# 迭代次数: 211 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 211	准确率: 48/48 (100%)
#
# 迭代次数: 212 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 212	准确率: 48/48 (100%)
#
# 迭代次数: 213 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 213	准确率: 48/48 (100%)
#
# 迭代次数: 214 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 214	准确率: 48/48 (100%)
#
# 迭代次数: 215 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 215	准确率: 48/48 (100%)
#
# 迭代次数: 216 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 216	准确率: 48/48 (100%)
#
# 迭代次数: 217 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 217	准确率: 48/48 (100%)
#
# 迭代次数: 218 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 218	准确率: 48/48 (100%)
#
# 迭代次数: 219 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 219	准确率: 48/48 (100%)
#
# 迭代次数: 220 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 220	准确率: 48/48 (100%)
#
# 迭代次数: 221 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 221	准确率: 48/48 (100%)
#
# 迭代次数: 222 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 222	准确率: 48/48 (100%)
#
# 迭代次数: 223 [0/254 (0%)]	训练损失: 0.017676
#
# 迭代次数 223	准确率: 48/48 (100%)
#
# 迭代次数: 224 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 224	准确率: 48/48 (100%)
#
# 迭代次数: 225 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 225	准确率: 48/48 (100%)
#
# 迭代次数: 226 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 226	准确率: 48/48 (100%)
#
# 迭代次数: 227 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 227	准确率: 48/48 (100%)
#
# 迭代次数: 228 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 228	准确率: 48/48 (100%)
#
# 迭代次数: 229 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 229	准确率: 48/48 (100%)
#
# 迭代次数: 230 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 230	准确率: 48/48 (100%)
#
# 迭代次数: 231 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 231	准确率: 48/48 (100%)
#
# 迭代次数: 232 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 232	准确率: 48/48 (100%)
#
# 迭代次数: 233 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 233	准确率: 48/48 (100%)
#
# 迭代次数: 234 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 234	准确率: 48/48 (100%)
#
# 迭代次数: 235 [0/254 (0%)]	训练损失: 0.017675
#
# 迭代次数 235	准确率: 48/48 (100%)
#
# 迭代次数: 236 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 236	准确率: 48/48 (100%)
#
# 迭代次数: 237 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 237	准确率: 48/48 (100%)
#
# 迭代次数: 238 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 238	准确率: 48/48 (100%)
#
# 迭代次数: 239 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 239	准确率: 48/48 (100%)
#
# 迭代次数: 240 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 240	准确率: 48/48 (100%)
#
# 迭代次数: 241 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 241	准确率: 48/48 (100%)
#
# 迭代次数: 242 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 242	准确率: 48/48 (100%)
#
# 迭代次数: 243 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 243	准确率: 48/48 (100%)
#
# 迭代次数: 244 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 244	准确率: 48/48 (100%)
#
# 迭代次数: 245 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 245	准确率: 48/48 (100%)
#
# 迭代次数: 246 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 246	准确率: 48/48 (100%)
#
# 迭代次数: 247 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 247	准确率: 48/48 (100%)
#
# 迭代次数: 248 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 248	准确率: 48/48 (100%)
#
# 迭代次数: 249 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 249	准确率: 48/48 (100%)
#
# 迭代次数: 250 [0/254 (0%)]	训练损失: 0.017674
#
# 迭代次数 250	准确率: 48/48 (100%)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35757 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32451 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21518 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20934 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30830 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21518 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20934 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30830 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 根据输入计算其分类

# %%
def predict(tensor):
    # 使用已经训练过的神经网络来预测
    tensor = tensor.to(device)
    tensor = transform(tensor)
    tensor = model(tensor.unsqueeze(0))
    tensor = get_likely_index(tensor)
    tensor = index_to_label(tensor.squeeze())
    return tensor


waveform, sample_rate, utterance, *_ = train_set[-1]

print(f"期望: {utterance}. 预测结果: {predict(waveform)}.")
ipd.Audio(waveform.numpy(), rate=sample_rate)
# Out:
# 期望: (打)开后备箱. 预测结果: (打)开后备箱.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 以下是一个分类不成功的例子

# %%
for i, (waveform, sample_rate, utterance, *_) in enumerate(test_set):
    output = predict(waveform)
    if output != utterance:
        print(f"数据 #{i}. 期望: {utterance}. 预测结果: {output}.")
        ipd.Audio(waveform.numpy(), rate=sample_rate)
        break
else:
    print("所有数据均完全正确！这并不应该出现，请检查数据集是否太小或训练集与测试集重复")
    ipd.Audio(waveform.numpy(), rate=sample_rate)
ipd.Audio(waveform.numpy(), rate=sample_rate)
# Out:
# 所有数据均完全正确！这并不应该出现，请检查数据集是否太小或训练集与测试集重复
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 录音并尝试

# %%
import sys
# js代码，录制3秒音频
def record(seconds = 3):

    from google.colab import output as colab_output
    from base64 import b64decode
    from io import BytesIO
    from pydub import AudioSegment

    RECORD = (
        b"const sleep  = time => new Promise(resolve => setTimeout(resolve, time))\n"
        b"const b2text = blob => new Promise(resolve => {\n"
        b"  const reader = new FileReader()\n"
        b"  reader.onloadend = e => resolve(e.srcElement.result)\n"
        b"  reader.readAsDataURL(blob)\n"
        b"})\n"
        b"var record = time => new Promise(async resolve => {\n"
        b"  stream = await navigator.mediaDevices.getUserMedia({ audio: true })\n"
        b"  recorder = new MediaRecorder(stream)\n"
        b"  chunks = []\n"
        b"  recorder.ondataavailable = e => chunks.push(e.data)\n"
        b"  recorder.start()\n"
        b"  await sleep(time)\n"
        b"  recorder.onstop = async ()=>{\n"
        b"    blob = new Blob(chunks)\n"
        b"    text = await b2text(blob)\n"
        b"    resolve(text)\n"
        b"  }\n"
        b"  recorder.stop()\n"
        b"})"
    )
    RECORD = RECORD.decode("ascii")

    print(f"录音开始，将持续 {seconds} 秒.")
    display(ipd.Javascript(RECORD))
    s = colab_output.eval_js("record(%d)" % (seconds * 1000))
    print("录音结束")
    b = b64decode(s.split(",")[1])

    # 录音格式定义
    fileformat = "wav"
    filename = f"_audio.{fileformat}"
    AudioSegment.from_file(BytesIO(b)).export(filename, format=fileformat)
    return torchaudio.load(filename)


waveform, sample_rate = record()
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
waveform_t = transform(waveform)
print(f"预测结果： {predict(waveform)}.")

ipd.Audio(waveform_t.numpy(), rate = new_sample_rate)
# Out:
# 录音开始，将持续 3 秒.
# 录音结束
# 预测结果： (关)闭后备箱.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 可以看出，搭建的神经网络准确率高，且具有不让人失望的泛化能力

# %%
file = "./Speech-Recognize-via-CNN/校验文件/" + "关闭后备箱0.wav"
waveform, sample_rate = torchaudio.load(file)
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
waveform_t = transform(waveform)
print(f"预测结果： {predict(waveform)}.")

ipd.Audio(waveform_t.numpy(), rate = new_sample_rate)
# Out:
# 预测结果： (关)闭后备箱.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#torch.save(model, './drive/MyDrive/M5_CNN.pt')
#torch.save(model.state_dict(), './drive/MyDrive/M5_CNN.pth')
